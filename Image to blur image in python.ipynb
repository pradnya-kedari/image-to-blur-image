# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\pradnya\anaconda3\envs\tensorflow\lib\site-packages (4.4.0.40)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\pradnya\anaconda3\envs\tensorflow\lib\site-packages (from opencv-python) (1.19.1)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('cat.png')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv2.GaussianBlur(img,(5,5),0)

# %%
cv2.imshow('Gaussian Blurring', blur)

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
median = cv2.medianBlur(img,5)
cv2.imshow('Media Blurring', median) 
cv2.waitKey(0)
# Out:
# -1

# %%
blur = cv2.bilateralFilter(img,9,75,75)
cv2.imshow('Bilateral Filtering', blur) 
cv2.waitKey(0)
# Out:
# -1
